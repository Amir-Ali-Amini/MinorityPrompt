# %%
# !pip install torch torchvision torchaudio
# !pip install dlib opencv-python pandas tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: dlib in /usr/local/lib/python3.12/dist-packages (19.24.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_path = "/content/drive/MyDrive/TTI_results.zip"
extract_to = "/content/TTI_results"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
import os


images_dir = "/content/TTI_results/TTI_results/generated_images"

for fname in os.listdir(images_dir):
    full_path = os.path.join(images_dir, fname)
    if os.path.isdir(full_path):
        continue

    # Add .png if the file has no extension
    name, ext = os.path.splitext(fname)
    if ext == "":
        new_name = fname + ".png"
        new_path = os.path.join(images_dir, new_name)
        os.rename(full_path, new_path)
        print(f"Renamed: {fname} → {new_name}")

original_paths = sorted([
    os.path.join(images_dir, fname)
    for fname in os.listdir(images_dir)
    if "_original" in fname.lower() and fname.lower().endswith((".png", ".jpg"))
])

enhanced_paths = sorted([
    os.path.join(images_dir, fname)
    for fname in os.listdir(images_dir)
    if "_enhanced" in fname.lower() and fname.lower().endswith((".png", ".jpg"))
])

print(f"\nOriginal images found: {len(original_paths)}")
print(f"Enhanced images found: {len(enhanced_paths)}")

print("\nSample originals:", original_paths[:3])
print("Sample enhanced:", enhanced_paths[:3])
# Out:
# Renamed: sample_357_enhanced → sample_357_enhanced.png
# Renamed: sample_606_original → sample_606_original.png
# Renamed: sample_795_enhanced → sample_795_enhanced.png
# Renamed: sample_637_enhanced → sample_637_enhanced.png
# Renamed: sample_789_enhanced → sample_789_enhanced.png
# Renamed: sample_619_original → sample_619_original.png
# Renamed: sample_717_original → sample_717_original.png
# Renamed: sample_784_enhanced → sample_784_enhanced.png
# Renamed: sample_182_original → sample_182_original.png
# Renamed: sample_906_original → sample_906_original.png
# Renamed: sample_329_enhanced → sample_329_enhanced.png
# Renamed: sample_065_original → sample_065_original.png
# Renamed: sample_351_original → sample_351_original.png
# Renamed: sample_672_enhanced → sample_672_enhanced.png
# Renamed: sample_900_enhanced → sample_900_enhanced.png
# Renamed: sample_287_enhanced → sample_287_enhanced.png
# Renamed: sample_940_original → sample_940_original.png
# Renamed: sample_401_original → sample_401_original.png
# Renamed: sample_357_original → sample_357_original.png
# Renamed: sample_572_original → sample_572_original.png
# Renamed: sample_813_enhanced → sample_813_enhanced.png
# Renamed: sample_850_enhanced → sample_850_enhanced.png
# Renamed: sample_345_original → sample_345_original.png
# Renamed: sample_491_original → sample_491_original.png
# Renamed: sample_654_original → sample_654_original.png
# Renamed: sample_040_enhanced → sample_040_enhanced.png
# Renamed: sample_860_original → sample_860_original.png
# Renamed: sample_201_enhanced → sample_201_enhanced.png
# Renamed: sample_215_original → sample_215_original.png
# Renamed: sample_859_original → sample_859_original.png
# Renamed: sample_091_enhanced → sample_091_enhanced.png
# Renamed: sample_584_enhanced → sample_584_enhanced.png
# Renamed: sample_746_original → sample_746_original.png
# Renamed: sample_061_enhanced → sample_061_enhanced.png
# Renamed: sample_240_enhanced → sample_240_enhanced.png
# Renamed: sample_025_original → sample_025_original.png
# Renamed: sample_830_original → sample_830_original.png
# Renamed: sample_397_enhanced → sample_397_enhanced.png
# Renamed: sample_867_enhanced → sample_867_enhanced.png
# Renamed: sample_377_original → sample_377_original.png
# Renamed: sample_909_enhanced → sample_909_enhanced.png
# Renamed: sample_338_original → sample_338_original.png
# Renamed: sample_453_enhanced → sample_453_enhanced.png
# Renamed: sample_576_enhanced → sample_576_enhanced.png
# Renamed: sample_643_original → sample_643_original.png
# Renamed: sample_825_original → sample_825_original.png
# Renamed: sample_121_enhanced → sample_121_enhanced.png
# Renamed: sample_439_original → sample_439_original.png
# Renamed: sample_110_enhanced → sample_110_enhanced.png
# Renamed: sample_519_enhanced → sample_519_enhanced.png
# Renamed: sample_704_enhanced → sample_704_enhanced.png
# Renamed: sample_395_enhanced → sample_395_enhanced.png
# Renamed: sample_406_enhanced → sample_406_enhanced.png
# Renamed: sample_161_original → sample_161_original.png
# Renamed: sample_371_enhanced → sample_371_enhanced.png
# Renamed: sample_290_original → sample_290_original.png
# Renamed: sample_935_enhanced → sample_935_enhanced.png
# Renamed: sample_733_original → sample_733_original.png
# Renamed: sample_719_original → sample_719_original.png
# Renamed: sample_531_enhanced → sample_531_enhanced.png
# Renamed: sample_632_original → sample_632_original.png
# Renamed: sample_451_original → sample_451_original.png
# Renamed: sample_076_enhanced → sample_076_enhanced.png
# Renamed: sample_385_original → sample_385_original.png
# Renamed: sample_816_enhanced → sample_816_enhanced.png
# Renamed: sample_883_original → sample_883_original.png
# Renamed: sample_907_enhanced → sample_907_enhanced.png
# Renamed: sample_379_enhanced → sample_379_enhanced.png
# Renamed: sample_868_enhanced → sample_868_enhanced.png
# Renamed: sample_276_enhanced → sample_276_enhanced.png
# Renamed: sample_172_enhanced → sample_172_enhanced.png
# Renamed: sample_853_original → sample_853_original.png
# Renamed: sample_980_enhanced → sample_980_enhanced.png
# Renamed: sample_082_enhanced → sample_082_enhanced.png
# Renamed: sample_583_original → sample_583_original.png
# Renamed: sample_417_original → sample_417_original.png
# Renamed: sample_227_original → sample_227_original.png
# Renamed: sample_973_original → sample_973_original.png
# Renamed: sample_936_enhanced → sample_936_enhanced.png
# Renamed: sample_231_original → sample_231_original.png
# Renamed: sample_847_original → sample_847_original.png
# Renamed: sample_582_original → sample_582_original.png
# Renamed: sample_304_enhanced → sample_304_enhanced.png
# Renamed: sample_117_enhanced → sample_117_enhanced.png
# Renamed: sample_821_original → sample_821_original.png
# Renamed: sample_840_original → sample_840_original.png
# Renamed: sample_257_original → sample_257_original.png
# Renamed: sample_639_original → sample_639_original.png
# Renamed: sample_532_original → sample_532_original.png
# Renamed: sample_446_original → sample_446_original.png
# Renamed: sample_171_original → sample_171_original.png
# Renamed: sample_788_original → sample_788_original.png
# Renamed: sample_056_original → sample_056_original.png
# Renamed: sample_036_enhanced → sample_036_enhanced.png
# Renamed: sample_185_original → sample_185_original.png
# Renamed: sample_620_enhanced → sample_620_enhanced.png
# Renamed: sample_077_original → sample_077_original.png
# Renamed: sample_582_enhanced → sample_582_enhanced.png
# Renamed: sample_797_original → sample_797_original.png
# Renamed: sample_222_original → sample_222_original.png
# Renamed: sample_703_original → sample_703_original.png
# Renamed: sample_213_original → sample_213_original.png
# Renamed: sample_465_original → sample_465_original.png
# Renamed: sample_817_enhanced → sample_817_enhanced.png
# Renamed: sample_561_original → sample_561_original.png
# Renamed: sample_854_original → sample_854_original.png
# Renamed: sample_525_original → sample_525_original.png
# Renamed: sample_690_original → sample_690_original.png
# Renamed: sample_053_enhanced → sample_053_enhanced.png
# Renamed: sample_714_enhanced → sample_714_enhanced.png
# Renamed: sample_154_original → sample_154_original.png
# Renamed: sample_440_enhanced → sample_440_enhanced.png
# Renamed: sample_147_enhanced → sample_147_enhanced.png
# Renamed: sample_903_enhanced → sample_903_enhanced.png
# Renamed: sample_573_enhanced → sample_573_enhanced.png
# Renamed: sample_691_original → sample_691_original.png
# Renamed: sample_889_enhanced → sample_889_enhanced.png
# Renamed: sample_513_enhanced → sample_513_enhanced.png
# Renamed: sample_555_enhanced → sample_555_enhanced.png
# Renamed: sample_046_enhanced → sample_046_enhanced.png
# Renamed: sample_334_original → sample_334_original.png
# Renamed: sample_641_original → sample_641_original.png
# Renamed: sample_394_enhanced → sample_394_enhanced.png
# Renamed: sample_468_original → sample_468_original.png
# Renamed: sample_963_enhanced → sample_963_enhanced.png
# Renamed: sample_706_enhanced → sample_706_enhanced.png
# Renamed: sample_308_enhanced → sample_308_enhanced.png
# Renamed: sample_885_enhanced → sample_885_enhanced.png
# Renamed: sample_795_original → sample_795_original.png
# Renamed: sample_807_enhanced → sample_807_enhanced.png
# Renamed: sample_295_original → sample_295_original.png
# Renamed: sample_838_enhanced → sample_838_enhanced.png
# Renamed: sample_825_enhanced → sample_825_enhanced.png
# Renamed: sample_893_enhanced → sample_893_enhanced.png
# Renamed: sample_129_enhanced → sample_129_enhanced.png
# Renamed: sample_223_original → sample_223_original.png
# Renamed: sample_362_enhanced → sample_362_enhanced.png
# Renamed: sample_688_original → sample_688_original.png
# Renamed: sample_104_enhanced → sample_104_enhanced.png
# Renamed: sample_710_enhanced → sample_710_enhanced.png
# Renamed: sample_722_enhanced → sample_722_enhanced.png
# Renamed: sample_619_enhanced → sample_619_enhanced.png
# Renamed: sample_735_enhanced → sample_735_enhanced.png
# Renamed: sample_226_original → sample_226_original.png
# Renamed: sample_653_enhanced → sample_653_enhanced.png
# Renamed: sample_073_enhanced → sample_073_enhanced.png
# Renamed: sample_433_original → sample_433_original.png
# Renamed: sample_332_enhanced → sample_332_enhanced.png
# Renamed: sample_752_original → sample_752_original.png
# Renamed: sample_480_enhanced → sample_480_enhanced.png
# Renamed: sample_650_enhanced → sample_650_enhanced.png
# Renamed: sample_910_original → sample_910_original.png
# Renamed: sample_404_original → sample_404_original.png
# Renamed: sample_904_original → sample_904_original.png
# Renamed: sample_697_enhanced → sample_697_enhanced.png
# Renamed: sample_281_enhanced → sample_281_enhanced.png
# Renamed: sample_794_enhanced → sample_794_enhanced.png
# Renamed: sample_496_enhanced → sample_496_enhanced.png
# Renamed: sample_607_original → sample_607_original.png
# Renamed: sample_471_original → sample_471_original.png
# Renamed: sample_682_original → sample_682_original.png
# Renamed: sample_661_enhanced → sample_661_enhanced.png
# Renamed: sample_383_original → sample_383_original.png
# Renamed: sample_685_enhanced → sample_685_enhanced.png
# Renamed: sample_956_enhanced → sample_956_enhanced.png
# Renamed: sample_616_enhanced → sample_616_enhanced.png
# Renamed: sample_314_enhanced → sample_314_enhanced.png
# Renamed: sample_258_original → sample_258_original.png
# Renamed: sample_944_original → sample_944_original.png
# Renamed: sample_541_original → sample_541_original.png
# Renamed: sample_698_enhanced → sample_698_enhanced.png
# Renamed: sample_837_enhanced → sample_837_enhanced.png
# Renamed: sample_085_enhanced → sample_085_enhanced.png
# Renamed: sample_501_enhanced → sample_501_enhanced.png
# Renamed: sample_884_enhanced → sample_884_enhanced.png
# Renamed: sample_983_enhanced → sample_983_enhanced.png
# Renamed: sample_737_enhanced → sample_737_enhanced.png
# Renamed: sample_323_enhanced → sample_323_enhanced.png
# Renamed: sample_420_enhanced → sample_420_enhanced.png
# Renamed: sample_593_enhanced → sample_593_enhanced.png
# Renamed: sample_543_original → sample_543_original.png
# Renamed: sample_268_enhanced → sample_268_enhanced.png
# Renamed: sample_310_original → sample_310_original.png
# Renamed: sample_134_enhanced → sample_134_enhanced.png
# Renamed: sample_860_enhanced → sample_860_enhanced.png
# Renamed: sample_325_enhanced → sample_325_enhanced.png
# Renamed: sample_360_original → sample_360_original.png
# Renamed: sample_951_original → sample_951_original.png
# Renamed: sample_427_original → sample_427_original.png
# Renamed: sample_616_original → sample_616_original.png
# Renamed: sample_261_enhanced → sample_261_enhanced.png
# Renamed: sample_523_original → sample_523_original.png
# Renamed: sample_856_enhanced → sample_856_enhanced.png
# Renamed: sample_394_original → sample_394_original.png
# Renamed: sample_319_enhanced → sample_319_enhanced.png
# Renamed: sample_901_enhanced → sample_901_enhanced.png
# Renamed: sample_026_enhanced → sample_026_enhanced.png
# Renamed: sample_028_enhanced → sample_028_enhanced.png
# Renamed: sample_241_original → sample_241_original.png
# Renamed: sample_645_original → sample_645_original.png
# Renamed: sample_113_enhanced → sample_113_enhanced.png
# Renamed: sample_553_original → sample_553_original.png
# Renamed: sample_161_enhanced → sample_161_enhanced.png
# Renamed: sample_924_enhanced → sample_924_enhanced.png
# Renamed: sample_008_original → sample_008_original.png
# Renamed: sample_214_enhanced → sample_214_enhanced.png
# Renamed: sample_344_original → sample_344_original.png
# Renamed: sample_095_enhanced → sample_095_enhanced.png
# Renamed: sample_302_enhanced → sample_302_enhanced.png
# Renamed: sample_371_original → sample_371_original.png
# Renamed: sample_773_original → sample_773_original.png
# Renamed: sample_112_enhanced → sample_112_enhanced.png
# Renamed: sample_021_enhanced → sample_021_enhanced.png
# Renamed: sample_956_original → sample_956_original.png
# Renamed: sample_509_original → sample_509_original.png
# Renamed: sample_076_original → sample_076_original.png
# Renamed: sample_756_original → sample_756_original.png
# Renamed: sample_567_original → sample_567_original.png
# Renamed: sample_861_enhanced → sample_861_enhanced.png
# Renamed: sample_615_original → sample_615_original.png
# Renamed: sample_306_original → sample_306_original.png
# Renamed: sample_351_enhanced → sample_351_enhanced.png
# Renamed: sample_080_original → sample_080_original.png
# Renamed: sample_004_original → sample_004_original.png
# Renamed: sample_343_enhanced → sample_343_enhanced.png
# Renamed: sample_817_original → sample_817_original.png
# Renamed: sample_480_original → sample_480_original.png
# Renamed: sample_281_original → sample_281_original.png
# Renamed: sample_549_original → sample_549_original.png
# Renamed: sample_607_enhanced → sample_607_enhanced.png
# Renamed: sample_765_enhanced → sample_765_enhanced.png
# Renamed: sample_152_enhanced → sample_152_enhanced.png
# Renamed: sample_469_enhanced → sample_469_enhanced.png
# Renamed: sample_170_original → sample_170_original.png
# Renamed: sample_835_original → sample_835_original.png
# Renamed: sample_852_enhanced → sample_852_enhanced.png
# Renamed: sample_425_enhanced → sample_425_enhanced.png
# Renamed: sample_078_original → sample_078_original.png
# Renamed: sample_796_enhanced → sample_796_enhanced.png
# Renamed: sample_487_enhanced → sample_487_enhanced.png
# Renamed: sample_207_original → sample_207_original.png
# Renamed: sample_713_enhanced → sample_713_enhanced.png
# Renamed: sample_223_enhanced → sample_223_enhanced.png
# Renamed: sample_284_enhanced → sample_284_enhanced.png
# Renamed: sample_695_original → sample_695_original.png
# Renamed: sample_591_original → sample_591_original.png
# Renamed: sample_181_enhanced → sample_181_enhanced.png
# Renamed: sample_022_original → sample_022_original.png
# Renamed: sample_275_original → sample_275_original.png
# Renamed: sample_762_original → sample_762_original.png
# Renamed: sample_419_enhanced → sample_419_enhanced.png
# Renamed: sample_048_enhanced → sample_048_enhanced.png
# Renamed: sample_305_enhanced → sample_305_enhanced.png
# Renamed: sample_831_enhanced → sample_831_enhanced.png
# Renamed: sample_187_enhanced → sample_187_enhanced.png
# Renamed: sample_512_enhanced → sample_512_enhanced.png
# Renamed: sample_459_original → sample_459_original.png
# Renamed: sample_867_original → sample_867_original.png
# Renamed: sample_925_original → sample_925_original.png
# Renamed: sample_108_enhanced → sample_108_enhanced.png
# Renamed: sample_381_original → sample_381_original.png
# Renamed: sample_428_enhanced → sample_428_enhanced.png
# Renamed: sample_507_enhanced → sample_507_enhanced.png
# Renamed: sample_505_original → sample_505_original.png
# Renamed: sample_373_original → sample_373_original.png
# Renamed: sample_982_original → sample_982_original.png
# Renamed: sample_088_enhanced → sample_088_enhanced.png
# Renamed: sample_132_enhanced → sample_132_enhanced.png
# Renamed: sample_101_original → sample_101_original.png
# Renamed: sample_014_enhanced → sample_014_enhanced.png
# Renamed: sample_708_original → sample_708_original.png
# Renamed: sample_962_original → sample_962_original.png
# Renamed: sample_436_original → sample_436_original.png
# Renamed: sample_988_enhanced → sample_988_enhanced.png
# Renamed: sample_898_original → sample_898_original.png
# Renamed: sample_163_enhanced → sample_163_enhanced.png
# Renamed: sample_734_enhanced → sample_734_enhanced.png
# Renamed: sample_427_enhanced → sample_427_enhanced.png
# Renamed: sample_959_original → sample_959_original.png
# Renamed: sample_032_enhanced → sample_032_enhanced.png
# Renamed: sample_216_enhanced → sample_216_enhanced.png
# Renamed: sample_580_enhanced → sample_580_enhanced.png
# Renamed: sample_502_enhanced → sample_502_enhanced.png
# Renamed: sample_949_enhanced → sample_949_enhanced.png
# Renamed: sample_442_enhanced → sample_442_enhanced.png
# Renamed: sample_045_enhanced → sample_045_enhanced.png
# Renamed: sample_366_enhanced → sample_366_enhanced.png
# Renamed: sample_823_original → sample_823_original.png
# Renamed: sample_845_original → sample_845_original.png
# Renamed: sample_876_original → sample_876_original.png
# Renamed: sample_508_original → sample_508_original.png
# Renamed: sample_741_enhanced → sample_741_enhanced.png
# Renamed: sample_327_original → sample_327_original.png
# Renamed: sample_174_enhanced → sample_174_enhanced.png
# Renamed: sample_523_enhanced → sample_523_enhanced.png
# Renamed: sample_431_original → sample_431_original.png
# Renamed: sample_416_enhanced → sample_416_enhanced.png
# Renamed: sample_890_original → sample_890_original.png
# Renamed: sample_660_original → sample_660_original.png
# Renamed: sample_272_enhanced → sample_272_enhanced.png
# Renamed: sample_979_original → sample_979_original.png
# Renamed: sample_800_original → sample_800_original.png
# Renamed: sample_857_original → sample_857_original.png
# Renamed: sample_587_original → sample_587_original.png
# Renamed: sample_874_enhanced → sample_874_enhanced.png
# Renamed: sample_558_enhanced → sample_558_enhanced.png
# Renamed: sample_257_enhanced → sample_257_enhanced.png
# Renamed: sample_651_original → sample_651_original.png
# Renamed: sample_808_enhanced → sample_808_enhanced.png
# Renamed: sample_675_enhanced → sample_675_enhanced.png
# Renamed: sample_079_enhanced → sample_079_enhanced.png
# Renamed: sample_727_enhanced → sample_727_enhanced.png
# Renamed: sample_353_enhanced → sample_353_enhanced.png
# Renamed: sample_475_enhanced → sample_475_enhanced.png
# Renamed: sample_597_original → sample_597_original.png
# Renamed: sample_481_original → sample_481_original.png
# Renamed: sample_627_enhanced → sample_627_enhanced.png
# Renamed: sample_339_enhanced → sample_339_enhanced.png
# Renamed: sample_004_enhanced → sample_004_enhanced.png
# Renamed: sample_307_enhanced → sample_307_enhanced.png
# Renamed: sample_548_original → sample_548_original.png
# Renamed: sample_995_enhanced → sample_995_enhanced.png
# Renamed: sample_970_original → sample_970_original.png
# Renamed: sample_978_original → sample_978_original.png
# Renamed: sample_547_enhanced → sample_547_enhanced.png
# Renamed: sample_586_enhanced → sample_586_enhanced.png
# Renamed: sample_693_original → sample_693_original.png
# Renamed: sample_063_original → sample_063_original.png
# Renamed: sample_636_original → sample_636_original.png
# Renamed: sample_754_enhanced → sample_754_enhanced.png
# Renamed: sample_192_original → sample_192_original.png
# Renamed: sample_499_enhanced → sample_499_enhanced.png
# Renamed: sample_133_enhanced → sample_133_enhanced.png
# Renamed: sample_804_original → sample_804_original.png
# Renamed: sample_391_enhanced → sample_391_enhanced.png
# Renamed: sample_761_original → sample_761_original.png
# Renamed: sample_149_original → sample_149_original.png
# Renamed: sample_662_original → sample_662_original.png
# Renamed: sample_792_original → sample_792_original.png
# Renamed: sample_456_enhanced → sample_456_enhanced.png
# Renamed: sample_605_original → sample_605_original.png
# Renamed: sample_977_original → sample_977_original.png
# Renamed: sample_212_enhanced → sample_212_enhanced.png
# Renamed: sample_376_enhanced → sample_376_enhanced.png
# Renamed: sample_368_enhanced → sample_368_enhanced.png
# Renamed: sample_120_enhanced → sample_120_enhanced.png
# Renamed: sample_415_original → sample_415_original.png
# Renamed: sample_098_enhanced → sample_098_enhanced.png
# Renamed: sample_018_original → sample_018_original.png
# Renamed: sample_202_original → sample_202_original.png
# Renamed: sample_993_enhanced → sample_993_enhanced.png
# Renamed: sample_309_original → sample_309_original.png
# Renamed: sample_350_enhanced → sample_350_enhanced.png
# Renamed: sample_613_original → sample_613_original.png
# Renamed: sample_103_enhanced → sample_103_enhanced.png
# Renamed: sample_960_enhanced → sample_960_enhanced.png
# Renamed: sample_729_original → sample_729_original.png
# Renamed: sample_657_original → sample_657_original.png
# Renamed: sample_965_original → sample_965_original.png
# Renamed: sample_805_original → sample_805_original.png
# Renamed: sample_730_original → sample_730_original.png
# Renamed: sample_923_enhanced → sample_923_enhanced.png
# Renamed: sample_017_enhanced → sample_017_enhanced.png
# Renamed: sample_485_enhanced → sample_485_enhanced.png
# Renamed: sample_469_original → sample_469_original.png
# Renamed: sample_080_enhanced → sample_080_enhanced.png
# Renamed: sample_450_enhanced → sample_450_enhanced.png
# Renamed: sample_932_enhanced → sample_932_enhanced.png
# Renamed: sample_672_original → sample_672_original.png
# Renamed: sample_433_enhanced → sample_433_enhanced.png
# Renamed: sample_895_original → sample_895_original.png
# Renamed: sample_290_enhanced → sample_290_enhanced.png
# Renamed: sample_998_enhanced → sample_998_enhanced.png
# Renamed: sample_745_enhanced → sample_745_enhanced.png
# Renamed: sample_236_enhanced → sample_236_enhanced.png
# Renamed: sample_490_original → sample_490_original.png
# Renamed: sample_342_enhanced → sample_342_enhanced.png
# Renamed: sample_678_enhanced → sample_678_enhanced.png
# Renamed: sample_738_original → sample_738_original.png
# Renamed: sample_838_original → sample_838_original.png
# Renamed: sample_209_enhanced → sample_209_enhanced.png
# Renamed: sample_858_enhanced → sample_858_enhanced.png
# Renamed: sample_857_enhanced → sample_857_enhanced.png
# Renamed: sample_230_original → sample_230_original.png
# Renamed: sample_622_original → sample_622_original.png
# Renamed: sample_798_original → sample_798_original.png
# Renamed: sample_143_enhanced → sample_143_enhanced.png
# Renamed: sample_360_enhanced → sample_360_enhanced.png
# Renamed: sample_094_enhanced → sample_094_enhanced.png
# Renamed: sample_438_enhanced → sample_438_enhanced.png
# Renamed: sample_399_enhanced → sample_399_enhanced.png
# Renamed: sample_762_enhanced → sample_762_enhanced.png
# Renamed: sample_631_enhanced → sample_631_enhanced.png
# Renamed: sample_844_original → sample_844_original.png
# Renamed: sample_539_enhanced → sample_539_enhanced.png
# Renamed: sample_265_enhanced → sample_265_enhanced.png
# Renamed: sample_686_original → sample_686_original.png
# Renamed: sample_946_original → sample_946_original.png
# Renamed: sample_404_enhanced → sample_404_enhanced.png
# Renamed: sample_651_enhanced → sample_651_enhanced.png
# Renamed: sample_313_enhanced → sample_313_enhanced.png
# Renamed: sample_640_original → sample_640_original.png
# Renamed: sample_864_original → sample_864_original.png
# Renamed: sample_540_original → sample_540_original.png
# Renamed: sample_758_enhanced → sample_758_enhanced.png
# Renamed: sample_822_enhanced → sample_822_enhanced.png
# Renamed: sample_848_original → sample_848_original.png
# Renamed: sample_849_enhanced → sample_849_enhanced.png
# Renamed: sample_153_original → sample_153_original.png
# Renamed: sample_522_enhanced → sample_522_enhanced.png
# Renamed: sample_093_enhanced → sample_093_enhanced.png
# Renamed: sample_437_original → sample_437_original.png
# Renamed: sample_242_original → sample_242_original.png
# Renamed: sample_731_enhanced → sample_731_enhanced.png
# Renamed: sample_232_original → sample_232_original.png
# Renamed: sample_402_original → sample_402_original.png
# Renamed: sample_128_enhanced → sample_128_enhanced.png
# Renamed: sample_097_enhanced → sample_097_enhanced.png
# Renamed: sample_643_enhanced → sample_643_enhanced.png
# Renamed: sample_574_enhanced → sample_574_enhanced.png
# Renamed: sample_589_enhanced → sample_589_enhanced.png
# Renamed: sample_206_enhanced → sample_206_enhanced.png
# Renamed: sample_359_enhanced → sample_359_enhanced.png
# Renamed: sample_203_original → sample_203_original.png
# Renamed: sample_410_enhanced → sample_410_enhanced.png
# Renamed: sample_487_original → sample_487_original.png
# Renamed: sample_663_original → sample_663_original.png
# Renamed: sample_096_original → sample_096_original.png
# Renamed: sample_208_enhanced → sample_208_enhanced.png
# Renamed: sample_545_original → sample_545_original.png
# Renamed: sample_700_original → sample_700_original.png
# Renamed: sample_033_enhanced → sample_033_enhanced.png
# Renamed: sample_726_original → sample_726_original.png
# Renamed: sample_969_enhanced → sample_969_enhanced.png
# Renamed: sample_446_enhanced → sample_446_enhanced.png
# Renamed: sample_109_enhanced → sample_109_enhanced.png
# Renamed: sample_694_enhanced → sample_694_enhanced.png
# Renamed: sample_420_original → sample_420_original.png
# Renamed: sample_864_enhanced → sample_864_enhanced.png
# Renamed: sample_977_enhanced → sample_977_enhanced.png
# Renamed: sample_186_enhanced → sample_186_enhanced.png
# Renamed: sample_767_enhanced → sample_767_enhanced.png
# Renamed: sample_518_original → sample_518_original.png
# Renamed: sample_812_enhanced → sample_812_enhanced.png
# Renamed: sample_922_enhanced → sample_922_enhanced.png
# Renamed: sample_879_enhanced → sample_879_enhanced.png
# Renamed: sample_087_enhanced → sample_087_enhanced.png
# Renamed: sample_914_original → sample_914_original.png
# Renamed: sample_728_enhanced → sample_728_enhanced.png
# Renamed: sample_524_original → sample_524_original.png
# Renamed: sample_529_original → sample_529_original.png
# Renamed: sample_537_original → sample_537_original.png
# Renamed: sample_892_enhanced → sample_892_enhanced.png
# Renamed: sample_888_original → sample_888_original.png
# Renamed: sample_765_original → sample_765_original.png
# Renamed: sample_038_enhanced → sample_038_enhanced.png
# Renamed: sample_298_enhanced → sample_298_enhanced.png
# Renamed: sample_392_enhanced → sample_392_enhanced.png
# Renamed: sample_674_original → sample_674_original.png
# Renamed: sample_481_enhanced → sample_481_enhanced.png
# Renamed: sample_688_enhanced → sample_688_enhanced.png
# Renamed: sample_163_original → sample_163_original.png
# Renamed: sample_943_original → sample_943_original.png
# Renamed: sample_389_original → sample_389_original.png
# Renamed: sample_901_original → sample_901_original.png
# Renamed: sample_598_enhanced → sample_598_enhanced.png
# Renamed: sample_669_original → sample_669_original.png
# Renamed: sample_401_enhanced → sample_401_enhanced.png
# Renamed: sample_354_enhanced → sample_354_enhanced.png
# Renamed: sample_698_original → sample_698_original.png
# Renamed: sample_913_enhanced → sample_913_enhanced.png
# Renamed: sample_911_original → sample_911_original.png
# Renamed: sample_048_original → sample_048_original.png
# Renamed: sample_316_enhanced → sample_316_enhanced.png
# Renamed: sample_434_original → sample_434_original.png
# Renamed: sample_989_original → sample_989_original.png
# Renamed: sample_193_enhanced → sample_193_enhanced.png
# Renamed: sample_907_original → sample_907_original.png
# Renamed: sample_150_original → sample_150_original.png
# Renamed: sample_173_enhanced → sample_173_enhanced.png
# Renamed: sample_725_original → sample_725_original.png
# Renamed: sample_142_original → sample_142_original.png
# Renamed: sample_367_original → sample_367_original.png
# Renamed: sample_127_enhanced → sample_127_enhanced.png
# Renamed: sample_033_original → sample_033_original.png
# Renamed: sample_912_original → sample_912_original.png
# Renamed: sample_981_enhanced → sample_981_enhanced.png
# Renamed: sample_418_enhanced → sample_418_enhanced.png
# Renamed: sample_496_original → sample_496_original.png
# Renamed: sample_309_enhanced → sample_309_enhanced.png
# Renamed: sample_605_enhanced → sample_605_enhanced.png
# Renamed: sample_312_enhanced → sample_312_enhanced.png
# Renamed: sample_766_enhanced → sample_766_enhanced.png
# Renamed: sample_151_original → sample_151_original.png
# Renamed: sample_497_original → sample_497_original.png
# Renamed: sample_011_enhanced → sample_011_enhanced.png
# Renamed: sample_721_original → sample_721_original.png
# Renamed: sample_157_enhanced → sample_157_enhanced.png
# Renamed: sample_016_enhanced → sample_016_enhanced.png
# Renamed: sample_217_original → sample_217_original.png
# Renamed: sample_939_original → sample_939_original.png
# Renamed: sample_209_original → sample_209_original.png
# Renamed: sample_320_original → sample_320_original.png
# Renamed: sample_931_original → sample_931_original.png
# Renamed: sample_215_enhanced → sample_215_enhanced.png
# Renamed: sample_418_original → sample_418_original.png
# Renamed: sample_488_enhanced → sample_488_enhanced.png
# Renamed: sample_622_enhanced → sample_622_enhanced.png
# Renamed: sample_361_enhanced → sample_361_enhanced.png
# Renamed: sample_878_original → sample_878_original.png
# Renamed: sample_551_original → sample_551_original.png
# Renamed: sample_535_enhanced → sample_535_enhanced.png
# Renamed: sample_434_enhanced → sample_434_enhanced.png
# Renamed: sample_015_original → sample_015_original.png
# Renamed: sample_447_enhanced → sample_447_enhanced.png
# Renamed: sample_787_original → sample_787_original.png
# Renamed: sample_880_original → sample_880_original.png
# Renamed: sample_301_original → sample_301_original.png
# Renamed: sample_423_original → sample_423_original.png
# Renamed: sample_841_original → sample_841_original.png
# Renamed: sample_988_original → sample_988_original.png
# Renamed: sample_036_original → sample_036_original.png
# Renamed: sample_755_original → sample_755_original.png
# Renamed: sample_070_enhanced → sample_070_enhanced.png
# Renamed: sample_934_enhanced → sample_934_enhanced.png
# Renamed: sample_347_enhanced → sample_347_enhanced.png
# Renamed: sample_942_enhanced → sample_942_enhanced.png
# Renamed: sample_261_original → sample_261_original.png
# Renamed: sample_673_enhanced → sample_673_enhanced.png
# Renamed: sample_677_original → sample_677_original.png
# Renamed: sample_347_original → sample_347_original.png
# Renamed: sample_640_enhanced → sample_640_enhanced.png
# Renamed: sample_452_enhanced → sample_452_enhanced.png
# Renamed: sample_267_enhanced → sample_267_enhanced.png
# Renamed: sample_897_enhanced → sample_897_enhanced.png
# Renamed: sample_944_enhanced → sample_944_enhanced.png
# Renamed: sample_068_enhanced → sample_068_enhanced.png
# Renamed: sample_652_original → sample_652_original.png
# Renamed: sample_625_enhanced → sample_625_enhanced.png
# Renamed: sample_787_enhanced → sample_787_enhanced.png
# Renamed: sample_834_original → sample_834_original.png
# Renamed: sample_413_enhanced → sample_413_enhanced.png
# Renamed: sample_702_original → sample_702_original.png
# Renamed: sample_233_original → sample_233_original.png
# Renamed: sample_623_original → sample_623_original.png
# Renamed: sample_528_enhanced → sample_528_enhanced.png
# Renamed: sample_759_original → sample_759_original.png
# Renamed: sample_330_original → sample_330_original.png
# Renamed: sample_763_original → sample_763_original.png
# Renamed: sample_435_enhanced → sample_435_enhanced.png
# Renamed: sample_895_enhanced → sample_895_enhanced.png
# Renamed: sample_328_original → sample_328_original.png
# Renamed: sample_918_enhanced → sample_918_enhanced.png
# Renamed: sample_045_original → sample_045_original.png
# Renamed: sample_763_enhanced → sample_763_enhanced.png
# Renamed: sample_422_original → sample_422_original.png
# Renamed: sample_886_enhanced → sample_886_enhanced.png
# Renamed: sample_696_enhanced → sample_696_enhanced.png
# Renamed: sample_363_original → sample_363_original.png
# Renamed: sample_374_original → sample_374_original.png
# Renamed: sample_573_original → sample_573_original.png
# Renamed: sample_162_original → sample_162_original.png
# Renamed: sample_946_enhanced → sample_946_enhanced.png
# Renamed: sample_966_original → sample_966_original.png
# Renamed: sample_384_enhanced → sample_384_enhanced.png
# Renamed: sample_991_original → sample_991_original.png
# Renamed: sample_847_enhanced → sample_847_enhanced.png
# Renamed: sample_719_enhanced → sample_719_enhanced.png
# Renamed: sample_205_enhanced → sample_205_enhanced.png
# Renamed: sample_160_enhanced → sample_160_enhanced.png
# Renamed: sample_179_enhanced → sample_179_enhanced.png
# Renamed: sample_767_original → sample_767_original.png
# Renamed: sample_892_original → sample_892_original.png
# Renamed: sample_096_enhanced → sample_096_enhanced.png
# Renamed: sample_783_enhanced → sample_783_enhanced.png
# Renamed: sample_629_enhanced → sample_629_enhanced.png
# Renamed: sample_091_original → sample_091_original.png
# Renamed: sample_037_original → sample_037_original.png
# Renamed: sample_022_enhanced → sample_022_enhanced.png
# Renamed: sample_409_enhanced → sample_409_enhanced.png
# Renamed: sample_170_enhanced → sample_170_enhanced.png
# Renamed: sample_120_original → sample_120_original.png
# Renamed: sample_484_enhanced → sample_484_enhanced.png
# Renamed: sample_113_original → sample_113_original.png
# Renamed: sample_665_enhanced → sample_665_enhanced.png
# Renamed: sample_648_enhanced → sample_648_enhanced.png
# Renamed: sample_526_original → sample_526_original.png
# Renamed: sample_346_original → sample_346_original.png
# Renamed: sample_183_original → sample_183_original.png
# Renamed: sample_862_enhanced → sample_862_enhanced.png
# Renamed: sample_623_enhanced → sample_623_enhanced.png
# Renamed: sample_958_original → sample_958_original.png
# Renamed: sample_638_original → sample_638_original.png
# Renamed: sample_609_original → sample_609_original.png
# Renamed: sample_668_original → sample_668_original.png
# Renamed: sample_536_original → sample_536_original.png
# Renamed: sample_771_original → sample_771_original.png
# Renamed: sample_224_enhanced → sample_224_enhanced.png
# Renamed: sample_499_original → sample_499_original.png
# Renamed: sample_702_enhanced → sample_702_enhanced.png
# Renamed: sample_162_enhanced → sample_162_enhanced.png
# Renamed: sample_228_original → sample_228_original.png
# Renamed: sample_865_enhanced → sample_865_enhanced.png
# Renamed: sample_574_original → sample_574_original.png
# Renamed: sample_553_enhanced → sample_553_enhanced.png
# Renamed: sample_488_original → sample_488_original.png
# Renamed: sample_920_original → sample_920_original.png
# Renamed: sample_178_original → sample_178_original.png
# Renamed: sample_140_enhanced → sample_140_enhanced.png
# Renamed: sample_431_enhanced → sample_431_enhanced.png
# Renamed: sample_130_original → sample_130_original.png
# Renamed: sample_019_original → sample_019_original.png
# Renamed: sample_112_original → sample_112_original.png
# Renamed: sample_479_enhanced → sample_479_enhanced.png
# Renamed: sample_110_original → sample_110_original.png
# Renamed: sample_372_enhanced → sample_372_enhanced.png
# Renamed: sample_691_enhanced → sample_691_enhanced.png
# Renamed: sample_346_enhanced → sample_346_enhanced.png
# Renamed: sample_681_original → sample_681_original.png
# Renamed: sample_802_original → sample_802_original.png
# Renamed: sample_568_original → sample_568_original.png
# Renamed: sample_032_original → sample_032_original.png
# Renamed: sample_280_original → sample_280_original.png
# Renamed: sample_308_original → sample_308_original.png
# Renamed: sample_146_original → sample_146_original.png
# Renamed: sample_543_enhanced → sample_543_enhanced.png
# Renamed: sample_274_enhanced → sample_274_enhanced.png
# Renamed: sample_066_enhanced → sample_066_enhanced.png
# Renamed: sample_882_enhanced → sample_882_enhanced.png
# Renamed: sample_320_enhanced → sample_320_enhanced.png
# Renamed: sample_984_enhanced → sample_984_enhanced.png
# Renamed: sample_708_enhanced → sample_708_enhanced.png
# Renamed: sample_243_enhanced → sample_243_enhanced.png
# Renamed: sample_264_enhanced → sample_264_enhanced.png
# Renamed: sample_466_enhanced → sample_466_enhanced.png
# Renamed: sample_244_original → sample_244_original.png
# Renamed: sample_286_enhanced → sample_286_enhanced.png
# Renamed: sample_884_original → sample_884_original.png
# Renamed: sample_845_enhanced → sample_845_enhanced.png
# Renamed: sample_128_original → sample_128_original.png
# Renamed: sample_406_original → sample_406_original.png
# Renamed: sample_063_enhanced → sample_063_enhanced.png
# Renamed: sample_506_enhanced → sample_506_enhanced.png
# Renamed: sample_470_original → sample_470_original.png
# Renamed: sample_294_enhanced → sample_294_enhanced.png
# Renamed: sample_599_enhanced → sample_599_enhanced.png
# Renamed: sample_871_original → sample_871_original.png
# Renamed: sample_948_original → sample_948_original.png
# Renamed: sample_333_enhanced → sample_333_enhanced.png
# Renamed: sample_779_enhanced → sample_779_enhanced.png
# Renamed: sample_926_original → sample_926_original.png
# Renamed: sample_189_original → sample_189_original.png
# Renamed: sample_240_original → sample_240_original.png
# Renamed: sample_065_enhanced → sample_065_enhanced.png
# Renamed: sample_118_enhanced → sample_118_enhanced.png
# Renamed: sample_268_original → sample_268_original.png
# Renamed: sample_689_enhanced → sample_689_enhanced.png
# Renamed: sample_408_original → sample_408_original.png
# Renamed: sample_789_original → sample_789_original.png
# Renamed: sample_850_original → sample_850_original.png
# Renamed: sample_315_enhanced → sample_315_enhanced.png
# Renamed: sample_556_original → sample_556_original.png
# Renamed: sample_659_enhanced → sample_659_enhanced.png
# Renamed: sample_458_original → sample_458_original.png
# Renamed: sample_386_original → sample_386_original.png
# Renamed: sample_180_enhanced → sample_180_enhanced.png
# Renamed: sample_521_original → sample_521_original.png
# Renamed: sample_075_enhanced → sample_075_enhanced.png
# Renamed: sample_219_original → sample_219_original.png
# Renamed: sample_422_enhanced → sample_422_enhanced.png
# Renamed: sample_682_enhanced → sample_682_enhanced.png
# Renamed: sample_908_original → sample_908_original.png
# Renamed: sample_502_original → sample_502_original.png
# Renamed: sample_155_original → sample_155_original.png
# Renamed: sample_443_enhanced → sample_443_enhanced.png
# Renamed: sample_806_enhanced → sample_806_enhanced.png
# Renamed: sample_088_original → sample_088_original.png
# Renamed: sample_013_enhanced → sample_013_enhanced.png
# Renamed: sample_061_original → sample_061_original.png
# Renamed: sample_071_original → sample_071_original.png
# Renamed: sample_777_original → sample_777_original.png
# Renamed: sample_595_original → sample_595_original.png
# Renamed: sample_547_original → sample_547_original.png
# Renamed: sample_313_original → sample_313_original.png
# Renamed: sample_751_enhanced → sample_751_enhanced.png
# Renamed: sample_151_enhanced → sample_151_enhanced.png
# Renamed: sample_303_original → sample_303_original.png
# Renamed: sample_254_enhanced → sample_254_enhanced.png
# Renamed: sample_803_enhanced → sample_803_enhanced.png
# Renamed: sample_102_original → sample_102_original.png
# Renamed: sample_967_enhanced → sample_967_enhanced.png
# Renamed: sample_952_original → sample_952_original.png
# Renamed: sample_675_original → sample_675_original.png
# Renamed: sample_712_enhanced → sample_712_enhanced.png
# Renamed: sample_247_enhanced → sample_247_enhanced.png
# Renamed: sample_467_original → sample_467_original.png
# Renamed: sample_676_original → sample_676_original.png
# Renamed: sample_978_enhanced → sample_978_enhanced.png
# Renamed: sample_987_original → sample_987_original.png
# Renamed: sample_044_enhanced → sample_044_enhanced.png
# Renamed: sample_188_original → sample_188_original.png
# Renamed: sample_524_enhanced → sample_524_enhanced.png
# Renamed: sample_655_original → sample_655_original.png
# Renamed: sample_236_original → sample_236_original.png
# Renamed: sample_329_original → sample_329_original.png
# Renamed: sample_294_original → sample_294_original.png
# Renamed: sample_208_original → sample_208_original.png
# Renamed: sample_064_original → sample_064_original.png
# Renamed: sample_722_original → sample_722_original.png
# Renamed: sample_340_original → sample_340_original.png
# Renamed: sample_886_original → sample_886_original.png
# Renamed: sample_386_enhanced → sample_386_enhanced.png
# Renamed: sample_235_enhanced → sample_235_enhanced.png
# Renamed: sample_612_original → sample_612_original.png
# Renamed: sample_078_enhanced → sample_078_enhanced.png
# Renamed: sample_579_enhanced → sample_579_enhanced.png
# Renamed: sample_910_enhanced → sample_910_enhanced.png
# Renamed: sample_921_original → sample_921_original.png
# Renamed: sample_897_original → sample_897_original.png
# Renamed: sample_249_original → sample_249_original.png
# Renamed: sample_049_original → sample_049_original.png
# Renamed: sample_975_original → sample_975_original.png
# Renamed: sample_263_enhanced → sample_263_enhanced.png
# Renamed: sample_602_enhanced → sample_602_enhanced.png
# Renamed: sample_896_enhanced → sample_896_enhanced.png
# Renamed: sample_807_original → sample_807_original.png
# Renamed: sample_947_enhanced → sample_947_enhanced.png
# Renamed: sample_720_original → sample_720_original.png
# Renamed: sample_680_original → sample_680_original.png
# Renamed: sample_235_original → sample_235_original.png
# Renamed: sample_551_enhanced → sample_551_enhanced.png
# Renamed: sample_362_original → sample_362_original.png
# Renamed: sample_397_original → sample_397_original.png
# Renamed: sample_081_enhanced → sample_081_enhanced.png
# Renamed: sample_661_original → sample_661_original.png
# Renamed: sample_211_enhanced → sample_211_enhanced.png
# Renamed: sample_237_original → sample_237_original.png
# Renamed: sample_139_original → sample_139_original.png
# Renamed: sample_176_original → sample_176_original.png
# Renamed: sample_092_enhanced → sample_092_enhanced.png
# Renamed: sample_511_original → sample_511_original.png
# Renamed: sample_958_enhanced → sample_958_enhanced.png
# Renamed: sample_533_original → sample_533_original.png
# Renamed: sample_429_original → sample_429_original.png
# Renamed: sample_479_original → sample_479_original.png
# Renamed: sample_590_original → sample_590_original.png
# Renamed: sample_187_original → sample_187_original.png
# Renamed: sample_101_enhanced → sample_101_enhanced.png
# Renamed: sample_780_enhanced → sample_780_enhanced.png
# Renamed: sample_430_enhanced → sample_430_enhanced.png
# Renamed: sample_793_original → sample_793_original.png
# Renamed: sample_903_original → sample_903_original.png
# Renamed: sample_576_original → sample_576_original.png
# Renamed: sample_591_enhanced → sample_591_enhanced.png
# Renamed: sample_510_enhanced → sample_510_enhanced.png
# Renamed: sample_018_enhanced → sample_018_enhanced.png
# Renamed: sample_922_original → sample_922_original.png
# Renamed: sample_363_enhanced → sample_363_enhanced.png
# Renamed: sample_482_enhanced → sample_482_enhanced.png
# Renamed: sample_856_original → sample_856_original.png
# Renamed: sample_289_enhanced → sample_289_enhanced.png
# Renamed: sample_358_enhanced → sample_358_enhanced.png
# Renamed: sample_415_enhanced → sample_415_enhanced.png
# Renamed: sample_331_original → sample_331_original.png
# Renamed: sample_881_enhanced → sample_881_enhanced.png
# Renamed: sample_750_original → sample_750_original.png
# Renamed: sample_686_enhanced → sample_686_enhanced.png
# Renamed: sample_146_enhanced → sample_146_enhanced.png
# Renamed: sample_583_enhanced → sample_583_enhanced.png
# Renamed: sample_703_enhanced → sample_703_enhanced.png
# Renamed: sample_959_enhanced → sample_959_enhanced.png
# Renamed: sample_211_original → sample_211_original.png
# Renamed: sample_630_enhanced → sample_630_enhanced.png
# Renamed: sample_149_enhanced → sample_149_enhanced.png
# Renamed: sample_929_enhanced → sample_929_enhanced.png
# Renamed: sample_072_original → sample_072_original.png
# Renamed: sample_393_original → sample_393_original.png
# Renamed: sample_890_enhanced → sample_890_enhanced.png
# Renamed: sample_262_enhanced → sample_262_enhanced.png
# Renamed: sample_628_original → sample_628_original.png
# Renamed: sample_055_original → sample_055_original.png
# Renamed: sample_030_enhanced → sample_030_enhanced.png
# Renamed: sample_380_enhanced → sample_380_enhanced.png
# Renamed: sample_116_original → sample_116_original.png
# Renamed: sample_713_original → sample_713_original.png
# Renamed: sample_955_original → sample_955_original.png
# Renamed: sample_212_original → sample_212_original.png
# Renamed: sample_145_original → sample_145_original.png
# Renamed: sample_996_original → sample_996_original.png
# Renamed: sample_057_original → sample_057_original.png
# Renamed: sample_625_original → sample_625_original.png
# Renamed: sample_098_original → sample_098_original.png
# Renamed: sample_243_original → sample_243_original.png
# Renamed: sample_626_enhanced → sample_626_enhanced.png
# Renamed: sample_849_original → sample_849_original.png
# Renamed: sample_516_enhanced → sample_516_enhanced.png
# Renamed: sample_635_original → sample_635_original.png
# Renamed: sample_376_original → sample_376_original.png
# Renamed: sample_297_enhanced → sample_297_enhanced.png
# Renamed: sample_621_enhanced → sample_621_enhanced.png
# Renamed: sample_957_enhanced → sample_957_enhanced.png
# Renamed: sample_323_original → sample_323_original.png
# Renamed: sample_990_original → sample_990_original.png
# Renamed: sample_321_enhanced → sample_321_enhanced.png
# Renamed: sample_300_enhanced → sample_300_enhanced.png
# Renamed: sample_924_original → sample_924_original.png
# Renamed: sample_720_enhanced → sample_720_enhanced.png
# Renamed: sample_435_original → sample_435_original.png
# Renamed: sample_013_original → sample_013_original.png
# Renamed: sample_072_enhanced → sample_072_enhanced.png
# Renamed: sample_732_original → sample_732_original.png
# Renamed: sample_979_enhanced → sample_979_enhanced.png
# Renamed: sample_930_original → sample_930_original.png
# Renamed: sample_287_original → sample_287_original.png
# Renamed: sample_177_enhanced → sample_177_enhanced.png
# Renamed: sample_644_original → sample_644_original.png
# Renamed: sample_738_enhanced → sample_738_enhanced.png
# Renamed: sample_992_enhanced → sample_992_enhanced.png
# Renamed: sample_041_enhanced → sample_041_enhanced.png
# Renamed: sample_518_enhanced → sample_518_enhanced.png
# Renamed: sample_669_enhanced → sample_669_enhanced.png
# Renamed: sample_486_enhanced → sample_486_enhanced.png
# Renamed: sample_900_original → sample_900_original.png
# Renamed: sample_880_enhanced → sample_880_enhanced.png
# Renamed: sample_790_enhanced → sample_790_enhanced.png
# Renamed: sample_046_original → sample_046_original.png
# Renamed: sample_904_enhanced → sample_904_enhanced.png
# Renamed: sample_204_original → sample_204_original.png
# Renamed: sample_482_original → sample_482_original.png
# Renamed: sample_429_enhanced → sample_429_enhanced.png
# Renamed: sample_866_enhanced → sample_866_enhanced.png
# Renamed: sample_973_enhanced → sample_973_enhanced.png
# Renamed: sample_670_original → sample_670_original.png
# Renamed: sample_887_original → sample_887_original.png
# Renamed: sample_015_enhanced → sample_015_enhanced.png
# Renamed: sample_217_enhanced → sample_217_enhanced.png
# Renamed: sample_913_original → sample_913_original.png
# Renamed: sample_403_original → sample_403_original.png
# Renamed: sample_222_enhanced → sample_222_enhanced.png
# Renamed: sample_589_original → sample_589_original.png
# Renamed: sample_566_enhanced → sample_566_enhanced.png
# Renamed: sample_399_original → sample_399_original.png
# Renamed: sample_877_enhanced → sample_877_enhanced.png
# Renamed: sample_883_enhanced → sample_883_enhanced.png
# Renamed: sample_154_enhanced → sample_154_enhanced.png
# Renamed: sample_457_enhanced → sample_457_enhanced.png
# Renamed: sample_352_original → sample_352_original.png
# Renamed: sample_521_enhanced → sample_521_enhanced.png
# Renamed: sample_799_original → sample_799_original.png
# Renamed: sample_855_original → sample_855_original.png
# Renamed: sample_390_enhanced → sample_390_enhanced.png
# Renamed: sample_133_original → sample_133_original.png
# Renamed: sample_467_enhanced → sample_467_enhanced.png
# Renamed: sample_444_original → sample_444_original.png
# Renamed: sample_534_enhanced → sample_534_enhanced.png
# Renamed: sample_840_enhanced → sample_840_enhanced.png
# Renamed: sample_848_enhanced → sample_848_enhanced.png
# Renamed: sample_609_enhanced → sample_609_enhanced.png
# Renamed: sample_931_enhanced → sample_931_enhanced.png
# Renamed: sample_819_original → sample_819_original.png
# Renamed: sample_748_original → sample_748_original.png
# Renamed: sample_356_original → sample_356_original.png
# Renamed: sample_190_enhanced → sample_190_enhanced.png
# Renamed: sample_909_original → sample_909_original.png
# Renamed: sample_804_enhanced → sample_804_enhanced.png
# Renamed: sample_831_original → sample_831_original.png
# Renamed: sample_298_original → sample_298_original.png
# Renamed: sample_233_enhanced → sample_233_enhanced.png
# Renamed: sample_089_enhanced → sample_089_enhanced.png
# Renamed: sample_968_original → sample_968_original.png
# Renamed: sample_710_original → sample_710_original.png
# Renamed: sample_953_original → sample_953_original.png
# ...
# Renamed: sample_919_enhanced → sample_919_enhanced.png
# Renamed: sample_041_original → sample_041_original.png
# Renamed: sample_759_enhanced → sample_759_enhanced.png
# Renamed: sample_055_enhanced → sample_055_enhanced.png
# Renamed: sample_891_original → sample_891_original.png
# Renamed: sample_696_original → sample_696_original.png
# Renamed: sample_164_enhanced → sample_164_enhanced.png
# Renamed: sample_006_original → sample_006_original.png
# Renamed: sample_256_enhanced → sample_256_enhanced.png
# Renamed: sample_296_original → sample_296_original.png
# Renamed: sample_871_enhanced → sample_871_enhanced.png
# Renamed: sample_234_enhanced → sample_234_enhanced.png
# Renamed: sample_276_original → sample_276_original.png
# Renamed: sample_137_original → sample_137_original.png
# Renamed: sample_175_enhanced → sample_175_enhanced.png
# Renamed: sample_322_original → sample_322_original.png
# Renamed: sample_757_original → sample_757_original.png
# Renamed: sample_179_original → sample_179_original.png
# Renamed: sample_166_enhanced → sample_166_enhanced.png
# Renamed: sample_970_enhanced → sample_970_enhanced.png
# Renamed: sample_400_original → sample_400_original.png
# Renamed: sample_020_enhanced → sample_020_enhanced.png
# Renamed: sample_504_original → sample_504_original.png
# Renamed: sample_550_enhanced → sample_550_enhanced.png
# Renamed: sample_455_original → sample_455_original.png
# Renamed: sample_442_original → sample_442_original.png
# Renamed: sample_802_enhanced → sample_802_enhanced.png
# Renamed: sample_525_enhanced → sample_525_enhanced.png
# Renamed: sample_156_original → sample_156_original.png
# Renamed: sample_171_enhanced → sample_171_enhanced.png
# Renamed: sample_872_original → sample_872_original.png
# Renamed: sample_238_original → sample_238_original.png
# Renamed: sample_387_enhanced → sample_387_enhanced.png
# Renamed: sample_950_original → sample_950_original.png
# Renamed: sample_141_enhanced → sample_141_enhanced.png
# Renamed: sample_549_enhanced → sample_549_enhanced.png
# Renamed: sample_863_original → sample_863_original.png
# Renamed: sample_069_original → sample_069_original.png
# Renamed: sample_656_original → sample_656_original.png
# Renamed: sample_842_enhanced → sample_842_enhanced.png
# Renamed: sample_932_original → sample_932_original.png
# Renamed: sample_559_original → sample_559_original.png
# Renamed: sample_829_original → sample_829_original.png
# Renamed: sample_950_enhanced → sample_950_enhanced.png
# Renamed: sample_494_enhanced → sample_494_enhanced.png
# Renamed: sample_038_original → sample_038_original.png
# Renamed: sample_260_enhanced → sample_260_enhanced.png
# Renamed: sample_460_original → sample_460_original.png
# Renamed: sample_027_enhanced → sample_027_enhanced.png
# Renamed: sample_012_enhanced → sample_012_enhanced.png
# Renamed: sample_009_original → sample_009_original.png
# Renamed: sample_538_enhanced → sample_538_enhanced.png
# Renamed: sample_035_original → sample_035_original.png
# Renamed: sample_939_enhanced → sample_939_enhanced.png
# Renamed: sample_614_original → sample_614_original.png
# Renamed: sample_369_enhanced → sample_369_enhanced.png
# Renamed: sample_039_original → sample_039_original.png
# Renamed: sample_757_enhanced → sample_757_enhanced.png
# Renamed: sample_426_original → sample_426_original.png
# Renamed: sample_432_original → sample_432_original.png
# Renamed: sample_631_original → sample_631_original.png
# Renamed: sample_826_original → sample_826_original.png
# Renamed: sample_999_enhanced → sample_999_enhanced.png
# Renamed: sample_777_enhanced → sample_777_enhanced.png
# Renamed: sample_189_enhanced → sample_189_enhanced.png
# Renamed: sample_725_enhanced → sample_725_enhanced.png
# Renamed: sample_497_enhanced → sample_497_enhanced.png
# Renamed: sample_086_enhanced → sample_086_enhanced.png
# Renamed: sample_967_original → sample_967_original.png
# Renamed: sample_633_original → sample_633_original.png
# Renamed: sample_824_original → sample_824_original.png
# Renamed: sample_705_enhanced → sample_705_enhanced.png
# Renamed: sample_594_original → sample_594_original.png
# Renamed: sample_728_original → sample_728_original.png
# Renamed: sample_464_enhanced → sample_464_enhanced.png
# Renamed: sample_082_original → sample_082_original.png
# Renamed: sample_782_enhanced → sample_782_enhanced.png
# Renamed: sample_771_enhanced → sample_771_enhanced.png
# Renamed: sample_109_original → sample_109_original.png
# Renamed: sample_921_enhanced → sample_921_enhanced.png
# Renamed: sample_758_original → sample_758_original.png
# Renamed: sample_413_original → sample_413_original.png
# Renamed: sample_796_original → sample_796_original.png
# Renamed: sample_648_original → sample_648_original.png
# Renamed: sample_183_enhanced → sample_183_enhanced.png
# Renamed: sample_466_original → sample_466_original.png
# Renamed: sample_972_original → sample_972_original.png
# Renamed: sample_138_original → sample_138_original.png
# Renamed: sample_990_enhanced → sample_990_enhanced.png
# Renamed: sample_332_original → sample_332_original.png
# Renamed: sample_806_original → sample_806_original.png
# Renamed: sample_776_enhanced → sample_776_enhanced.png
# Renamed: sample_919_original → sample_919_original.png
# Renamed: sample_245_enhanced → sample_245_enhanced.png
# Renamed: sample_001_enhanced → sample_001_enhanced.png
# Renamed: sample_336_original → sample_336_original.png
# Renamed: sample_786_enhanced → sample_786_enhanced.png
# Renamed: sample_407_original → sample_407_original.png
# Renamed: sample_994_enhanced → sample_994_enhanced.png
# Renamed: sample_272_original → sample_272_original.png
# Renamed: sample_960_original → sample_960_original.png
# Renamed: sample_297_original → sample_297_original.png
# Renamed: sample_269_enhanced → sample_269_enhanced.png
# Renamed: sample_712_original → sample_712_original.png
# Renamed: sample_136_enhanced → sample_136_enhanced.png
# Renamed: sample_034_original → sample_034_original.png
# Renamed: sample_780_original → sample_780_original.png
# Renamed: sample_565_original → sample_565_original.png
# Renamed: sample_195_enhanced → sample_195_enhanced.png
# Renamed: sample_815_original → sample_815_original.png
# Renamed: sample_042_original → sample_042_original.png
# Renamed: sample_438_original → sample_438_original.png
# Renamed: sample_321_original → sample_321_original.png
# Renamed: sample_571_enhanced → sample_571_enhanced.png
# Renamed: sample_647_enhanced → sample_647_enhanced.png
# Renamed: sample_460_enhanced → sample_460_enhanced.png
# Renamed: sample_387_original → sample_387_original.png
# Renamed: sample_083_enhanced → sample_083_enhanced.png
# Renamed: sample_552_enhanced → sample_552_enhanced.png
# Renamed: sample_090_original → sample_090_original.png
# Renamed: sample_542_enhanced → sample_542_enhanced.png
# Renamed: sample_084_enhanced → sample_084_enhanced.png
# Renamed: sample_515_original → sample_515_original.png
# Renamed: sample_519_original → sample_519_original.png
# Renamed: sample_318_original → sample_318_original.png
# Renamed: sample_142_enhanced → sample_142_enhanced.png
# Renamed: sample_207_enhanced → sample_207_enhanced.png
# Renamed: sample_943_enhanced → sample_943_enhanced.png
# Renamed: sample_596_original → sample_596_original.png
# Renamed: sample_227_enhanced → sample_227_enhanced.png
# Renamed: sample_365_enhanced → sample_365_enhanced.png
# Renamed: sample_660_enhanced → sample_660_enhanced.png
# Renamed: sample_941_original → sample_941_original.png
# Renamed: sample_042_enhanced → sample_042_enhanced.png
# Renamed: sample_378_enhanced → sample_378_enhanced.png
# Renamed: sample_541_enhanced → sample_541_enhanced.png
# Renamed: sample_783_original → sample_783_original.png
# Renamed: sample_454_enhanced → sample_454_enhanced.png
# Renamed: sample_678_original → sample_678_original.png
# Renamed: sample_736_original → sample_736_original.png
# Renamed: sample_121_original → sample_121_original.png
# Renamed: sample_810_enhanced → sample_810_enhanced.png
# Renamed: sample_006_enhanced → sample_006_enhanced.png
# Renamed: sample_407_enhanced → sample_407_enhanced.png
# Renamed: sample_396_original → sample_396_original.png
# Renamed: sample_002_enhanced → sample_002_enhanced.png
# Renamed: sample_302_original → sample_302_original.png
# Renamed: sample_453_original → sample_453_original.png
# Renamed: sample_071_enhanced → sample_071_enhanced.png
# Renamed: sample_476_enhanced → sample_476_enhanced.png
# Renamed: sample_439_enhanced → sample_439_enhanced.png
# Renamed: sample_750_enhanced → sample_750_enhanced.png
# Renamed: sample_414_enhanced → sample_414_enhanced.png
# Renamed: sample_339_original → sample_339_original.png
# Renamed: sample_985_enhanced → sample_985_enhanced.png
# Renamed: sample_324_enhanced → sample_324_enhanced.png
# Renamed: sample_167_original → sample_167_original.png
# Renamed: sample_744_original → sample_744_original.png
# Renamed: sample_322_enhanced → sample_322_enhanced.png
# Renamed: sample_405_original → sample_405_original.png
# Renamed: sample_915_original → sample_915_original.png
# Renamed: sample_237_enhanced → sample_237_enhanced.png
# Renamed: sample_501_original → sample_501_original.png
# Renamed: sample_234_original → sample_234_original.png
# Renamed: sample_852_original → sample_852_original.png
# Renamed: sample_444_enhanced → sample_444_enhanced.png
# Renamed: sample_355_original → sample_355_original.png
# Renamed: sample_100_enhanced → sample_100_enhanced.png
# Renamed: sample_634_enhanced → sample_634_enhanced.png
# Renamed: sample_134_original → sample_134_original.png
# Renamed: sample_068_original → sample_068_original.png
# Renamed: sample_344_enhanced → sample_344_enhanced.png
# Renamed: sample_550_original → sample_550_original.png
# Renamed: sample_810_original → sample_810_original.png
# Renamed: sample_984_original → sample_984_original.png
# Renamed: sample_684_enhanced → sample_684_enhanced.png
# Renamed: sample_744_enhanced → sample_744_enhanced.png
# Renamed: sample_527_original → sample_527_original.png
# Renamed: sample_693_enhanced → sample_693_enhanced.png
# Renamed: sample_317_enhanced → sample_317_enhanced.png
# Renamed: sample_389_enhanced → sample_389_enhanced.png
# Renamed: sample_687_original → sample_687_original.png
# Renamed: sample_348_enhanced → sample_348_enhanced.png
# Renamed: sample_658_enhanced → sample_658_enhanced.png
# Renamed: sample_745_original → sample_745_original.png
# Renamed: sample_378_original → sample_378_original.png
# Renamed: sample_165_enhanced → sample_165_enhanced.png
# Renamed: sample_238_enhanced → sample_238_enhanced.png
# Renamed: sample_742_original → sample_742_original.png
# Renamed: sample_655_enhanced → sample_655_enhanced.png
# Renamed: sample_148_original → sample_148_original.png
# Renamed: sample_424_original → sample_424_original.png
# Renamed: sample_477_enhanced → sample_477_enhanced.png
# Renamed: sample_458_enhanced → sample_458_enhanced.png
# Renamed: sample_899_enhanced → sample_899_enhanced.png
# Renamed: sample_459_enhanced → sample_459_enhanced.png
# Renamed: sample_673_original → sample_673_original.png
# Renamed: sample_265_original → sample_265_original.png
# Renamed: sample_106_enhanced → sample_106_enhanced.png
# Renamed: sample_365_original → sample_365_original.png
# Renamed: sample_556_enhanced → sample_556_enhanced.png
# Renamed: sample_994_original → sample_994_original.png
# Renamed: sample_070_original → sample_070_original.png
# Renamed: sample_833_enhanced → sample_833_enhanced.png
# Renamed: sample_255_original → sample_255_original.png
# Renamed: sample_102_enhanced → sample_102_enhanced.png
# Renamed: sample_333_original → sample_333_original.png
# Renamed: sample_029_original → sample_029_original.png
# Renamed: sample_483_original → sample_483_original.png
# Renamed: sample_602_original → sample_602_original.png
# Renamed: sample_928_enhanced → sample_928_enhanced.png
# Renamed: sample_432_enhanced → sample_432_enhanced.png
# Renamed: sample_118_original → sample_118_original.png
# Renamed: sample_349_enhanced → sample_349_enhanced.png
# Renamed: sample_858_original → sample_858_original.png
# Renamed: sample_232_enhanced → sample_232_enhanced.png
# Renamed: sample_359_original → sample_359_original.png
# Renamed: sample_628_enhanced → sample_628_enhanced.png
# Renamed: sample_513_original → sample_513_original.png
# Renamed: sample_846_original → sample_846_original.png
# Renamed: sample_221_original → sample_221_original.png
# Renamed: sample_653_original → sample_653_original.png
# Renamed: sample_462_original → sample_462_original.png
# Renamed: sample_680_enhanced → sample_680_enhanced.png
# Renamed: sample_477_original → sample_477_original.png
# Renamed: sample_220_enhanced → sample_220_enhanced.png
# Renamed: sample_148_enhanced → sample_148_enhanced.png
# Renamed: sample_306_enhanced → sample_306_enhanced.png
# Renamed: sample_791_enhanced → sample_791_enhanced.png
# Renamed: sample_781_enhanced → sample_781_enhanced.png
# Renamed: sample_288_original → sample_288_original.png
# Renamed: sample_456_original → sample_456_original.png
# Renamed: sample_169_enhanced → sample_169_enhanced.png
# Renamed: sample_252_original → sample_252_original.png
# Renamed: sample_654_enhanced → sample_654_enhanced.png
# Renamed: sample_087_original → sample_087_original.png
# Renamed: sample_630_original → sample_630_original.png
# Renamed: sample_483_enhanced → sample_483_enhanced.png
# Renamed: sample_862_original → sample_862_original.png
# Renamed: sample_920_enhanced → sample_920_enhanced.png
# Renamed: sample_741_original → sample_741_original.png
# Renamed: sample_167_enhanced → sample_167_enhanced.png
# Renamed: sample_239_enhanced → sample_239_enhanced.png
# Renamed: sample_776_original → sample_776_original.png
# Renamed: sample_683_enhanced → sample_683_enhanced.png
# Renamed: sample_369_original → sample_369_original.png
# Renamed: sample_514_enhanced → sample_514_enhanced.png
# Renamed: sample_043_enhanced → sample_043_enhanced.png
# Renamed: sample_798_enhanced → sample_798_enhanced.png
# Renamed: sample_156_enhanced → sample_156_enhanced.png
# Renamed: sample_436_enhanced → sample_436_enhanced.png
# Renamed: sample_587_enhanced → sample_587_enhanced.png
# Renamed: sample_114_enhanced → sample_114_enhanced.png
# Renamed: sample_658_original → sample_658_original.png
# Renamed: sample_578_enhanced → sample_578_enhanced.png
# Renamed: sample_753_original → sample_753_original.png
# Renamed: sample_258_enhanced → sample_258_enhanced.png
# Renamed: sample_803_original → sample_803_original.png
# Renamed: sample_593_original → sample_593_original.png
# Renamed: sample_752_enhanced → sample_752_enhanced.png
# Renamed: sample_972_enhanced → sample_972_enhanced.png
# Renamed: sample_770_enhanced → sample_770_enhanced.png
# Renamed: sample_800_enhanced → sample_800_enhanced.png
# Renamed: sample_448_enhanced → sample_448_enhanced.png
# Renamed: sample_875_original → sample_875_original.png
# Renamed: sample_934_original → sample_934_original.png
# Renamed: sample_727_original → sample_727_original.png
# Renamed: sample_563_enhanced → sample_563_enhanced.png
# Renamed: sample_445_enhanced → sample_445_enhanced.png
# Renamed: sample_595_enhanced → sample_595_enhanced.png
# Renamed: sample_937_original → sample_937_original.png
# Renamed: sample_355_enhanced → sample_355_enhanced.png
# Renamed: sample_472_enhanced → sample_472_enhanced.png
# Renamed: sample_766_original → sample_766_original.png
# Renamed: sample_426_enhanced → sample_426_enhanced.png
# Renamed: sample_577_enhanced → sample_577_enhanced.png
# Renamed: sample_781_original → sample_781_original.png
# Renamed: sample_411_original → sample_411_original.png
# Renamed: sample_834_enhanced → sample_834_enhanced.png
# Renamed: sample_711_original → sample_711_original.png
#
# Original images found: 1000
# Enhanced images found: 1000
#
# Sample originals: ['/content/TTI_results/TTI_results/generated_images/sample_001_original.png', '/content/TTI_results/TTI_results/generated_images/sample_002_original.png', '/content/TTI_results/TTI_results/generated_images/sample_003_original.png']
# Sample enhanced: ['/content/TTI_results/TTI_results/generated_images/sample_001_enhanced.png', '/content/TTI_results/TTI_results/generated_images/sample_002_enhanced.png', '/content/TTI_results/TTI_results/generated_images/sample_003_enhanced.png']

# %%
BASE_DIR = "/content/metrics_results"

# Pre-downloaded models
FAIRFACE_MODEL_DIR = os.path.join(BASE_DIR, "fair_face_model")
DLIB_MODEL_DIR = os.path.join(BASE_DIR, "dlib_models")

# Runtime folders & outputs
INPUT_DIR = images_dir
DETECTED_DIR = os.path.join(BASE_DIR, "detected_faces")
OUTPUT_CSV = os.path.join(BASE_DIR, "test_outputs.csv")
BIAS_W_CSV = os.path.join(BASE_DIR, "bias_w_metrics.csv")
BIAS_P_CSV = os.path.join(BASE_DIR, "bias_p_metrics.csv")
ENS_CSV = os.path.join(BASE_DIR, "ens.csv")
KL_CSV = os.path.join(BASE_DIR, "kl_divergence_metrics.csv")

os.makedirs(DETECTED_DIR, exist_ok=True)

# %%
import zipfile
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import torchvision
from torchvision import transforms
import dlib

# Utility to convert dlib rectangle to bounding box
def rect_to_bb(rect):
    x = rect.left()
    y = rect.top()
    w = rect.right() - x
    h = rect.bottom() - y
    return (x, y, w, h)

# Ensure directory exists
def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

# Softmax helper
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
# Detect faces and save aligned images
def detect_face(image_paths, SAVE_DETECTED_AT, default_max_size=800, size=300, padding=0.25):
    face_detector = dlib.get_frontal_face_detector()
    sp = dlib.shape_predictor(os.path.join(DLIB_MODEL_DIR, "shape_predictor_5_face_landmarks.dat"))

    for index, image_path in enumerate(image_paths):
        if index % 100 == 0:
            print('Processing image: %d/%d' % (index, len(image_paths)))
        img = dlib.load_rgb_image(image_path)

        old_height, old_width, _ = img.shape
        if old_width > old_height:
            new_width, new_height = default_max_size, int(default_max_size * old_height / old_width)
        else:
            new_width, new_height = int(default_max_size * old_width / old_height), default_max_size

        img = dlib.resize_image(img, rows=new_height, cols=new_width)

        dets = face_detector(img, 1)
        if len(dets) == 0:
            print("No face detected in: {}".format(image_path))
            continue

        faces = dlib.full_object_detections()
        for rect in dets:
            faces.append(sp(img, rect))

        images = dlib.get_face_chips(img, faces, size=size, padding=padding)
        for idx, image in enumerate(images):
            img_name = os.path.basename(image_path)
            base, ext = os.path.splitext(img_name)
            face_name = os.path.join(SAVE_DETECTED_AT, f"{base}_face{idx}{ext}")
            dlib.save_image(image, face_name)

# %%
def is_image_file(path):
    if not os.path.isfile(path):
        return False
    _, ext = os.path.splitext(path.lower())
    return ext in {'.jpg', '.jpeg', '.png', '.bmp'}

def predict_age_gender_race(save_prediction_at, imgs_path='detected_faces/'):
    # collect only real image files
    img_names = []
    for entry in os.listdir(imgs_path):
        full = os.path.join(imgs_path, entry)
        if is_image_file(full):
            img_names.append(full)

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Load pretrained models
    model_fair_7 = torchvision.models.resnet34(pretrained=True)
    model_fair_7.fc = nn.Linear(model_fair_7.fc.in_features, 18)
    model_fair_7.load_state_dict(
    torch.load(os.path.join(FAIRFACE_MODEL_DIR, "res34_fair_align_multi_7_20190809.pt"), map_location=device))

    model_fair_7 = model_fair_7.to(device).eval()

    # Image transforms
    trans = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    face_names = []
    race_preds_fair, gender_preds_fair, age_preds_fair = [], [], []
    race_scores_fair, gender_scores_fair, age_scores_fair = [], [], []

    for index, img_name in enumerate(img_names):
        if index % 100 == 0:
            print(f"Predicting: {index}/{len(img_names)}")

        # Defensive load
        try:
            image_raw = dlib.load_rgb_image(img_name)
        except Exception as e:
            print(f"Warning: skipping {img_name} (load error: {e})")
            continue

        # proceed
        face_names.append(img_name)
        image = trans(image_raw).view(1, 3, 224, 224).to(device)

        # fair 7 model
        outputs = model_fair_7(image).cpu().detach().numpy().squeeze()
        race_score = softmax(outputs[:7])
        gender_score = softmax(outputs[7:9])
        age_score = softmax(outputs[9:18])

        race_preds_fair.append(np.argmax(race_score))
        gender_preds_fair.append(np.argmax(gender_score))
        age_preds_fair.append(np.argmax(age_score))
        race_scores_fair.append(race_score)
        gender_scores_fair.append(gender_score)
        age_scores_fair.append(age_score)

    # Create dataframe
    result = pd.DataFrame({
        'face_name_align': face_names,
        'race_preds_fair': race_preds_fair,
        # 'race_preds_fair_4': race_preds_fair_4,
        'gender_preds_fair': gender_preds_fair,
        'age_preds_fair': age_preds_fair,
        'race_scores_fair': race_scores_fair,
        # 'race_scores_fair_4': race_scores_fair_4,
        'gender_scores_fair': gender_scores_fair,
        'age_scores_fair': age_scores_fair
    })

    # Decode labels
    race_labels_7 = ['White', 'Black', 'Latino_Hispanic', 'East Asian', 'Southeast Asian', 'Indian', 'Middle Eastern']
    race_labels_4 = ['White', 'Black', 'Asian', 'Indian']
    gender_labels = ['Male', 'Female']
    age_labels = ['0-2', '3-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70+']

    result['race'] = result['race_preds_fair'].apply(lambda x: race_labels_7[x])
    # result['race4'] = result['race_preds_fair_4'].apply(lambda x: race_labels_4[x])
    result['gender'] = result['gender_preds_fair'].apply(lambda x: gender_labels[x])
    result['age'] = result['age_preds_fair'].apply(lambda x: age_labels[x])

    # Drop raw prediction indices
    result = result.drop(columns=[
        'race_preds_fair',
        # 'race_preds_fair_4',
        'gender_preds_fair',
        'age_preds_fair'
    ])

    # Save cleaned result
    result.to_csv(save_prediction_at, index=False)
    print("Results saved to:", save_prediction_at)

# %%
race_labels = ['White', 'Black', 'Latino_Hispanic', 'East Asian', 'Southeast Asian', 'Indian', 'Middle Eastern']
gender_labels = ['Male', 'Female']
age_labels = ['0-2', '3-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70+']

attributes_dict = {
    'race': race_labels,
    'gender': gender_labels,
    'age': age_labels
}

# Define single attributes and combinations to analyze
combinations_to_analyze = [
    ['race'], ['gender'], ['age'],
    ['race', 'gender'], ['race', 'age'], ['gender', 'age'],
    ['race', 'gender', 'age']
]

# %%
def calculate_combined_bias_metrics(prediction_csv_path, bias_w_csv_path='bias_w_metrics.csv', bias_p_csv_path='bias_p_metrics.csv'):
    """
    Calculates Bias-W and Bias-P metrics for single and combined attributes
    and saves them to separate CSV files.
    """
    try:
        df = pd.read_csv(prediction_csv_path)
    except FileNotFoundError:
        print(f"Error: The file {prediction_csv_path} was not found.")
        return

    # Extract original image name from the face_name_align column
    df['original_image'] = df['face_name_align'].apply(lambda x: os.path.basename(x).split('_face')[0])

    bias_w_records = []
    bias_p_records = []

    for attribute_group in combinations_to_analyze:
        attr_group_name = '_'.join(attribute_group)

        # --- Calculate Bias-W (across overall results) ---
        na = 1
        for attr in attribute_group:
            na *= len(attributes_dict[attr])

        if len(attribute_group) == 1:
            attr_type = attribute_group[0]
            freq_w = df[attr_type].value_counts(normalize=True)
        else:
            freq_w = df.groupby(attribute_group).size() / len(df)

        bias_w_sum = 0

        # We need to iterate through all possible combinations for the sum
        if len(attribute_group) == 1:
            all_combs = attributes_dict[attribute_group[0]]
        elif len(attribute_group) == 2:
            all_combs = [(a, b) for a in attributes_dict[attribute_group[0]] for b in attributes_dict[attribute_group[1]]]
        else:
            all_combs = [(a, b, c) for a in attributes_dict[attribute_group[0]] for b in attributes_dict[attribute_group[1]] for c in attributes_dict[attribute_group[2]]]

        for comb in all_combs:
            if isinstance(comb, str):
                freq_a_w = freq_w.get(comb, 0)
            else:
                try:
                    freq_a_w = freq_w.loc[comb]
                except KeyError:
                    freq_a_w = 0
            bias_w_sum += (freq_a_w - (1 / na)) ** 2

        bias_w = np.sqrt((1 / na) * bias_w_sum)
        bias_w_records.append({
            'Attribute_Group': attr_group_name,
            'Bias-W': bias_w
        })

        # --- Calculate Bias-P (within each multi-face image) ---
        for image_name, group in df.groupby('original_image'):
            if len(group) > 1:
                if len(attribute_group) == 1:
                    attr_type = attribute_group[0]
                    freq_p = group[attr_type].value_counts(normalize=True)
                else:
                    freq_p = group.groupby(attribute_group).size() / len(group)

                bias_p_sum = 0
                for comb in all_combs:
                    if isinstance(comb, str):
                        freq_a_p = freq_p.get(comb, 0)
                    else:
                        try:
                            freq_a_p = freq_p.loc[comb]
                        except KeyError:
                            freq_a_p = 0
                    bias_p_sum += (freq_a_p - (1 / na)) ** 2

                bias_p = np.sqrt((1 / na) * bias_p_sum)

                bias_p_records.append({
                    'Original_Image': image_name,
                    'Attribute_Group': attr_group_name,
                    'Bias-P': bias_p
                })

    bias_w_df = pd.DataFrame(bias_w_records)
    bias_w_df.to_csv(bias_w_csv_path, index=False)
    print(f"Bias-W metrics saved to: {bias_w_csv_path}")

    bias_p_df = pd.DataFrame(bias_p_records)
    bias_p_df.to_csv(bias_p_csv_path, index=False)
    print(f"Bias-P metrics saved to: {bias_p_csv_path}")

# %%
from itertools import product

def calculate_ens_metrics(prediction_csv_path, output_csv='ens_metrics.csv'):
    """
    Calculates the Effective Number of Species (ENS) for the specified attributes
    and their combinations.

    ENS = exp(- Σ_g p_g * ln p_g), where p_g are the group proportions.
    """
    try:
        df = pd.read_csv(prediction_csv_path)
    except FileNotFoundError:
        print(f"Error: The file {prediction_csv_path} was not found.")
        return

    ens_records = []

    for attrs in combinations_to_analyze:
        attrs = list(attrs)
        # Consider only rows where all attributes in the combination are present
        mask = df[attrs].notna().all(axis=1)
        sub = df.loc[mask, attrs].copy()

        denom = len(sub)
        if denom == 0:
            ens_records.append({
                'Attribute': "+".join(attrs),
                'ENS': 0.0
            })
            continue

        label_universes = [attributes_dict[a] for a in attrs]
        all_groups = list(product(*label_universes))

        if len(attrs) == 1:
            counts = sub[attrs[0]].value_counts().to_dict()
            p_list = []
            for lab in attributes_dict[attrs[0]]:
                c = counts.get(lab, 0)
                p_list.append(c / denom)
        else:
            counts = sub.value_counts().to_dict()
            p_list = []
            for grp in all_groups:
                c = counts.get(tuple(grp), 0)
                p_list.append(c / denom)

        # Compute Σ p_g ln p_g (ignore p_g = 0 terms)
        sum_p_ln_p = 0.0
        for p_g in p_list:
            if p_g > 0:
                sum_p_ln_p += p_g * np.log(p_g)

        ens_value = float(np.exp(-sum_p_ln_p))

        ens_records.append({
            'Attribute': "+".join(attrs),
            'ENS': ens_value
        })

    ens_df = pd.DataFrame(ens_records)
    ens_df.to_csv(output_csv, index=False)
    print(f"ENS metrics saved to: {output_csv}")

# %%
import itertools

def calculate_kl_divergence(
    prediction_csv_path,
    output_csv='kl_divergence_metrics.csv',
    reference_distribution=None
):
    """
    Calculates KL Divergence for race, gender, age, and intersectional combinations.

    Parameters:
    - prediction_csv_path: CSV file with columns ['race', 'gender', 'age'].
    - output_csv: Path to save results.
    - reference_distribution: dict (optional) specifying reference distributions for
      each attribute or combination. Example:
        {
            'race': {'White': 0.4, 'Black': 0.3, ...},
            'race_gender': {('White','Male'): 0.2, ('White','Female'): 0.2, ...}
        }
      If None, assumes uniform distribution for each case.
    """
    try:
        df = pd.read_csv(prediction_csv_path)
    except FileNotFoundError:
        print(f"Error: The file {prediction_csv_path} was not found.")
        return

    kl_records = []

    for attribute_group in combinations_to_analyze:
        attr_group_name = '_'.join(attribute_group)

        # Generated distribution
        if len(attribute_group) == 1:
            gen_dist = df[attribute_group[0]].value_counts(normalize=True)
        else:
            gen_dist = df.groupby(attribute_group).size() / len(df)

        # Reference distribution
        if reference_distribution and attr_group_name in reference_distribution:
            ref_dist = pd.Series(reference_distribution[attr_group_name])
        else:
            # Uniform distribution
            if len(attribute_group) == 1:
                labels = attributes_dict[attribute_group[0]]
            else:
                labels = list(itertools.product(*(attributes_dict[attr] for attr in attribute_group)))
            ref_dist = pd.Series({label: 1/len(labels) for label in labels})

        all_labels = sorted(set(gen_dist.index) | set(ref_dist.index))
        gen_probs = np.array([gen_dist.get(label, 0) for label in all_labels], dtype=float)
        ref_probs = np.array([ref_dist.get(label, 0) for label in all_labels], dtype=float)

        # Clip to avoid log(0)
        eps = 1e-12
        gen_probs = np.clip(gen_probs, eps, 1)
        ref_probs = np.clip(ref_probs, eps, 1)

        # KL Divergence
        kl_value = np.sum(gen_probs * np.log(gen_probs / ref_probs))

        kl_records.append({
            'Attribute_Group': attr_group_name,
            'KL_Divergence': kl_value
        })

    kl_df = pd.DataFrame(kl_records)
    kl_df.to_csv(output_csv, index=False)
    print(f"KL Divergence metrics saved to: {output_csv}")

# %%
def process_drive_and_predict(
    input_dir=INPUT_DIR,
    output_csv=OUTPUT_CSV,
    bias_p_csv=BIAS_P_CSV,
    bias_w_csv=BIAS_W_CSV,
    ens_csv=ENS_CSV,
    kl_csv=KL_CSV
):
    ensure_dir(DETECTED_DIR)

    print("Reading images from Google Drive...")

    img_paths = []
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                print("processing image: ", file.lower())
                img_paths.append(os.path.join(root, file))

    # Save image paths CSV
    input_csv_path = os.path.join(BASE_DIR, "image_paths.csv")
    pd.DataFrame({'img_path': img_paths}).to_csv(input_csv_path, index=False)

    # Run detection + predictions + metrics
    detect_face(img_paths, DETECTED_DIR)
    predict_age_gender_race(output_csv, DETECTED_DIR)

    calculate_combined_bias_metrics(output_csv, bias_w_csv, bias_p_csv)
    calculate_ens_metrics(output_csv, ens_csv)
    calculate_kl_divergence(output_csv, kl_csv)

# %%
# === New: run pipeline separately for originals and enhanced ===

def process_paths_and_predict(img_paths, tag):
    """
    Minimal wrapper to reuse existing logic while separating outputs per image set.
    - img_paths: list of file paths to images
    - tag: short suffix like "original" or "enhanced"
    This preserves the core logic but changes only I/O destinations.
    """
    detected_dir = os.path.join(BASE_DIR, f"detected_faces_{tag}")
    ensure_dir(detected_dir)

    output_csv = os.path.join(BASE_DIR, f"test_outputs_{tag}.csv")
    bias_p_csv = os.path.join(BASE_DIR, f"bias_p_metrics_{tag}.csv")
    bias_w_csv = os.path.join(BASE_DIR, f"bias_w_metrics_{tag}.csv")  # will be deleted right after creation
    ens_csv = os.path.join(BASE_DIR, f"ens_{tag}.csv")
    kl_csv = os.path.join(BASE_DIR, f"kl_divergence_metrics_{tag}.csv")

    # Save the list of image paths used for this run (optional but handy for audit)
    img_list_csv = os.path.join(BASE_DIR, f"image_paths_{tag}.csv")
    pd.DataFrame({'img_path': img_paths}).to_csv(img_list_csv, index=False)

    # Run pipeline (reusing existing functions)
    detect_face(img_paths, detected_dir)
    predict_age_gender_race(output_csv, detected_dir)

    # Save metrics
    calculate_combined_bias_metrics(output_csv, bias_w_csv, bias_p_csv)
    calculate_ens_metrics(output_csv, ens_csv)
    calculate_kl_divergence(output_csv, kl_csv)

# Now run for both sets:
process_paths_and_predict(original_paths, "original")
process_paths_and_predict(enhanced_paths, "enhanced")
# Out:
# Processing image: 0/1000
# Processing image: 100/1000
# Processing image: 200/1000
# Processing image: 300/1000
# Processing image: 400/1000
# Processing image: 500/1000
# Processing image: 600/1000
# Processing image: 700/1000
# Processing image: 800/1000
# Processing image: 900/1000
# No face detected in: /content/TTI_results/TTI_results/generated_images/sample_903_original.png
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 173MB/s]
# Predicting: 0/3978
# Predicting: 100/3978
# Predicting: 200/3978
# Predicting: 300/3978
# Predicting: 400/3978
# Predicting: 500/3978
# Predicting: 600/3978
# Predicting: 700/3978
# Predicting: 800/3978
# Predicting: 900/3978
# Predicting: 1000/3978
# Predicting: 1100/3978
# Predicting: 1200/3978
# Predicting: 1300/3978
# Predicting: 1400/3978
# Predicting: 1500/3978
# Predicting: 1600/3978
# Predicting: 1700/3978
# Predicting: 1800/3978
# Predicting: 1900/3978
# Predicting: 2000/3978
# Predicting: 2100/3978
# Predicting: 2200/3978
# Predicting: 2300/3978
# Predicting: 2400/3978
# Predicting: 2500/3978
# Predicting: 2600/3978
# Predicting: 2700/3978
# Predicting: 2800/3978
# Predicting: 2900/3978
# Predicting: 3000/3978
# Predicting: 3100/3978
# Predicting: 3200/3978
# Predicting: 3300/3978
# Predicting: 3400/3978
# Predicting: 3500/3978
# Predicting: 3600/3978
# Predicting: 3700/3978
# Predicting: 3800/3978
# Predicting: 3900/3978
# Results saved to: /content/metrics_results/test_outputs_original.csv
# Bias-W metrics saved to: /content/metrics_results/bias_w_metrics_original.csv
# Bias-P metrics saved to: /content/metrics_results/bias_p_metrics_original.csv
# ENS metrics saved to: /content/metrics_results/ens_original.csv
# KL Divergence metrics saved to: /content/metrics_results/kl_divergence_metrics_original.csv
# Processing image: 0/1000
# Processing image: 100/1000
# Processing image: 200/1000
# Processing image: 300/1000
# Processing image: 400/1000
# Processing image: 500/1000
# Processing image: 600/1000
# Processing image: 700/1000
# Processing image: 800/1000
# Processing image: 900/1000
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Predicting: 0/4441
# Predicting: 100/4441
# Predicting: 200/4441
# Predicting: 300/4441
# Predicting: 400/4441
# Predicting: 500/4441
# Predicting: 600/4441
# Predicting: 700/4441
# Predicting: 800/4441
# Predicting: 900/4441
# Predicting: 1000/4441
# Predicting: 1100/4441
# Predicting: 1200/4441
# Predicting: 1300/4441
# Predicting: 1400/4441
# Predicting: 1500/4441
# Predicting: 1600/4441
# Predicting: 1700/4441
# Predicting: 1800/4441
# Predicting: 1900/4441
# Predicting: 2000/4441
# Predicting: 2100/4441
# Predicting: 2200/4441
# Predicting: 2300/4441
# Predicting: 2400/4441
# Predicting: 2500/4441
# Predicting: 2600/4441
# Predicting: 2700/4441
# Predicting: 2800/4441
# Predicting: 2900/4441
# Predicting: 3000/4441
# Predicting: 3100/4441
# Predicting: 3200/4441
# Predicting: 3300/4441
# Predicting: 3400/4441
# Predicting: 3500/4441
# Predicting: 3600/4441
# Predicting: 3700/4441
# Predicting: 3800/4441
# Predicting: 3900/4441
# Predicting: 4000/4441
# Predicting: 4100/4441
# Predicting: 4200/4441
# Predicting: 4300/4441
# Predicting: 4400/4441
# Results saved to: /content/metrics_results/test_outputs_enhanced.csv
# Bias-W metrics saved to: /content/metrics_results/bias_w_metrics_enhanced.csv
# Bias-P metrics saved to: /content/metrics_results/bias_p_metrics_enhanced.csv
# ENS metrics saved to: /content/metrics_results/ens_enhanced.csv
# KL Divergence metrics saved to: /content/metrics_results/kl_divergence_metrics_enhanced.csv

# %%
# === Zip & Download: detected faces and metrics (original vs enhanced) ===
import os, zipfile, glob
from datetime import datetime

# Try to import Colab downloader if available
try:
    from google.colab import files as colab_files
except Exception:
    colab_files = None

def zip_dir(dir_path, zip_path):
    os.makedirs(os.path.dirname(zip_path), exist_ok=True)
    with zipfile.ZipFile(zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
        for root, _, files in os.walk(dir_path):
            for fname in files:
                fpath = os.path.join(root, fname)
                arcname = os.path.relpath(fpath, start=dir_path)
                zf.write(fpath, arcname)
    print(f"Created: {zip_path}")
    if colab_files:
        colab_files.download(zip_path)

def zip_files(file_paths, zip_path):
    os.makedirs(os.path.dirname(zip_path), exist_ok=True)
    with zipfile.ZipFile(zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
        for f in file_paths:
            if os.path.exists(f):
                zf.write(f, os.path.basename(f))
            else:
                print(f"Warning: missing file not added: {f}")
    print(f"Created: {zip_path}")
    if colab_files:
        colab_files.download(zip_path)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Detected faces folders produced by the wrapper
detected_original = os.path.join(BASE_DIR, "detected_faces_original")
detected_enhanced = os.path.join(BASE_DIR, "detected_faces_enhanced")

detected_original_zip = os.path.join(BASE_DIR, f"detected_faces_original_{timestamp}.zip")
detected_enhanced_zip = os.path.join(BASE_DIR, f"detected_faces_enhanced_{timestamp}.zip")

if os.path.isdir(detected_original):
    zip_dir(detected_original, detected_original_zip)
else:
    print(f"Detected faces folder not found: {detected_original}")

if os.path.isdir(detected_enhanced):
    zip_dir(detected_enhanced, detected_enhanced_zip)
else:
    print(f"Detected faces folder not found: {detected_enhanced}")

# Metrics CSVs (separate zips for original vs enhanced)
metrics_original = [
    os.path.join(BASE_DIR, "test_outputs_original.csv"),
    os.path.join(BASE_DIR, "bias_p_metrics_original.csv"),
    os.path.join(BASE_DIR, "bias_w_metrics_original.csv"),
    os.path.join(BASE_DIR, "ens_original.csv"),
    os.path.join(BASE_DIR, "kl_divergence_metrics_original.csv"),
]
metrics_enhanced = [
    os.path.join(BASE_DIR, "test_outputs_enhanced.csv"),
    os.path.join(BASE_DIR, "bias_p_metrics_enhanced.csv"),
    os.path.join(BASE_DIR, "bias_w_metrics_enhanced.csv"),
    os.path.join(BASE_DIR, "ens_enhanced.csv"),
    os.path.join(BASE_DIR, "kl_divergence_metrics_enhanced.csv"),
]

# (Bias-W is intentionally NOT included)

metrics_original_zip = os.path.join(BASE_DIR, f"metrics_original_{timestamp}.zip")
metrics_enhanced_zip = os.path.join(BASE_DIR, f"metrics_enhanced_{timestamp}.zip")

zip_files(metrics_original, metrics_original_zip)
zip_files(metrics_enhanced, metrics_enhanced_zip)

print("Done preparing zips.")
# Out:
# Created: /content/metrics_results/detected_faces_original_20251028_191733.zip
# Created: /content/metrics_results/detected_faces_enhanced_20251028_191733.zip
# Created: /content/metrics_results/metrics_original_20251028_191733.zip
# Created: /content/metrics_results/metrics_enhanced_20251028_191733.zip
# Done preparing zips.
